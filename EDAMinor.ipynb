# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt
from sqlalchemy import create_engine


plt.style.use('ggplot')

ProductsReviewsCC = pd.read_csv('productsreviews_cleaned_filled.csv')

# %%
ProductsReviewsCC
# Out:
#      product_id                                       product_name  \
# 0       P473671                            Fragrance Discovery Set
# 1       P473668                            La Habana Eau de Parfum
# 2       P473662                          Rainbow Bar Eau de Parfum
# 3       P473660                               Kasbah Eau de Parfum
# 4       P473658                          Purple Haze Eau de Parfum
# ...         ...                                                ...
# 8489    P467659                   Couture Clutch Eyeshadow Palette
# 8490    P500874                              L'Homme Eau de Parfum
# 8491    P504428                   Mon Paris Eau de Parfum Gift Set
# 8492    P504448                           Y Eau de Parfum Gift Set
# 8493    P505461  Candy Glaze Lip Gloss Stick Duo with Hyaluroni...
#
#               brand_name  loves_count   rating  reviews  price_usd  \
# 0                  19-69         6320  3.63640     11.0       35.0
# ...

# %%
ProductsReviewsCC.shape
# Out:
# (8494, 10)

# %%
ProductsReviewsCC.columns
# Out:
# Index(['product_id', 'product_name', 'brand_name', 'loves_count', 'rating',
#        'reviews', 'price_usd', 'primary_category', 'secondary_category',
#        'tertiary_category'],
#       dtype='object')

# %%
ProductsReviewsCC.dtypes
# Out:
# product_id             object
# product_name           object
# brand_name             object
# loves_count             int64
# rating                float64
# reviews               float64
# price_usd             float64
# primary_category       object
# secondary_category     object
# tertiary_category      object
# dtype: object

# %%
ProductsReviewsCC.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8494 entries, 0 to 8493
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   product_id          8494 non-null   object
#  1   product_name        8494 non-null   object
#  2   brand_name          8494 non-null   object
#  3   loves_count         8494 non-null   int64
#  4   rating              8494 non-null   float64
#  5   reviews             8494 non-null   float64
#  6   price_usd           8494 non-null   float64
#  7   primary_category    8494 non-null   object
#  8   secondary_category  8486 non-null   object
#  9   tertiary_category   7504 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 663.7+ KB

# %%
# Displaying primary product category

plt.figure(figsize=(12, 6))

ProductsReviewsCC['primary_category'].value_counts().iloc[::-1].plot(kind='barh', color='maroon', edgecolor='black')

plt.title('Primary Product Category')
plt.xlabel('Count')
plt.tight_layout()
plt.show()

# %%
# Displaying Secondary product categories

plt.figure(figsize=(12, 12))

ProductsReviewsCC['secondary_category'].value_counts().iloc[::-1].plot(kind='barh', color='lightcoral', edgecolor='dimgrey')

plt.title('Secondary Product Category')
plt.xlabel('Count')

plt.tight_layout()
plt.show()

# %%
# Displaying Tertiary Category. Category used for recommendations.

plt.figure(figsize=(12, 12))

ProductsReviewsCC['tertiary_category'].value_counts().iloc[::-1].plot(kind='barh', color='lightcoral', edgecolor='dimgrey')

plt.title('Tertiary Category')
plt.xlabel('Count')

plt.tight_layout()
plt.show()
